# %% [markdown]
# This project consists of a practical application of building Dashboards with Streamlit, generating a data app for visualizing air accident data.

# %%
# Import libraries for the project and put in a variable the url address where the csv file is located
import pandas as pd

DATA_URL = "https://raw.githubusercontent.com/zorrex82/aeronautical_occurrence/master/ocorrencias_aviacao.csv"

# import the csv file
data = pd.read_csv(DATA_URL, index_col='codigo_ocorrencia')

# show the first 5 rows
data.head()
# Out:
#                   ocorrencia_classificacao  ... ocorrencia_dia_extracao
# codigo_ocorrencia                           ...
# 201305055424986                   ACIDENTE  ...              2018-08-28
# 201605160250139            INCIDENTE GRAVE  ...              2018-08-28
# 201805021421302                  INCIDENTE  ...              2018-08-28
# 201311259977425            INCIDENTE GRAVE  ...              2018-08-28
# 201103187273112                  INCIDENTE  ...              2018-08-28
#
# [5 rows x 21 columns]

# %% [markdown]
# Create a dictionary with only the columns that will be used and the standardized names for each of these columns

# %%
columns = {
        'ocorrencia_latitude': 'latitude',
        'ocorrencia_longitude': 'longitude',
        'ocorrencia_dia': 'data',
        'ocorrencia_classificacao': 'classificacao',
        'ocorrencia_tipo': 'tipo',
        'ocorrencia_tipo_categoria': 'tipo_categoria',
        'ocorrencia_tipo_icao': 'tipo_icao',
        'ocorrencia_aerodromo': 'aerodromo',
        'ocorrencia_cidade': 'cidade',
        'investigacao_status': 'status',
        'divulgacao_relatorio_numero': 'relatorio_numero',
        'total_aeronaves_envolvidas': 'aeronaves_envolvidas'
    }

# %%
data = data.rename(columns=columns)
data.head()
# Out:
#                      classificacao  ... ocorrencia_dia_extracao
# codigo_ocorrencia                   ...
# 201305055424986           ACIDENTE  ...              2018-08-28
# 201605160250139    INCIDENTE GRAVE  ...              2018-08-28
# 201805021421302          INCIDENTE  ...              2018-08-28
# 201311259977425    INCIDENTE GRAVE  ...              2018-08-28
# 201103187273112          INCIDENTE  ...              2018-08-28
#
# [5 rows x 21 columns]

# %% [markdown]
# Convert the format of the `data` column to the` datetime` format

# %%
data.data
# Out:
# codigo_ocorrencia
# 201305055424986    2013-05-05
# 201605160250139    2016-05-13
# 201805021421302    2018-03-09
# 201311259977425    2013-11-25
# 201103187273112    2011-03-18
#                       ...
# 200811264169752    2008-11-26
# 200910311058203    2009-10-31
# 200810318709738    2008-10-31
# 200803063018556    2008-03-06
# 201309012098180    2013-09-02
# Name: data, Length: 5208, dtype: object

# %%
data.data = data.data + " " + data.ocorrencia_horario
data.data = pd.to_datetime(data.data)

# see the results
data.data
# Out:
# codigo_ocorrencia
# 201305055424986   2013-05-05 11:00:00
# 201605160250139   2016-05-13 19:19:00
# 201805021421302   2018-03-09 22:40:00
# 201311259977425   2013-11-25 12:32:00
# 201103187273112   2011-03-18 13:30:00
#                           ...
# 200811264169752   2008-11-26 16:40:00
# 200910311058203   2009-10-31 12:10:00
# 200810318709738   2008-10-31 18:00:00
# 200803063018556   2008-03-06 07:55:00
# 201309012098180   2013-09-02 02:54:00
# Name: data, Length: 5208, dtype: datetime64[ns]

# %%
data.head()
# Out:
#                      classificacao  ... ocorrencia_dia_extracao
# codigo_ocorrencia                   ...
# 201305055424986           ACIDENTE  ...              2018-08-28
# 201605160250139    INCIDENTE GRAVE  ...              2018-08-28
# 201805021421302          INCIDENTE  ...              2018-08-28
# 201311259977425    INCIDENTE GRAVE  ...              2018-08-28
# 201103187273112          INCIDENTE  ...              2018-08-28
#
# [5 rows x 21 columns]

# %% [markdown]
# Select only the columns that will be used in the Streamlit app (will return the `load_data ()` function

# %%
data[list(columns.values())]
# Out:
#                    latitude  ...  aeronaves_envolvidas
# codigo_ocorrencia            ...
# 201305055424986     -9.9085  ...                     1
# 201605160250139    -11.2644  ...                     1
# 201805021421302    -11.4956  ...                     1
# 201311259977425    -11.4956  ...                     1
# 201103187273112    -13.1950  ...                     1
# ...                     ...  ...                   ...
# 200811264169752      0.0000  ...                     1
# 200910311058203      0.0000  ...                     1
# 200810318709738      0.0000  ...                     1
# 200803063018556      0.0000  ...                     1
# 201309012098180      6.7119  ...                     1
#
# [5208 rows x 12 columns]

# %%
data.classificacao.unique().tolist()
# Out:
# ['ACIDENTE', 'INCIDENTE GRAVE', 'INCIDENTE']

# %%
data[(data.data.dt.year == 2017) & (data.classificacao.isin(['ACIDENTE']))]
# Out:
#                   classificacao  ... ocorrencia_dia_extracao
# codigo_ocorrencia                ...
# 201711152026161        ACIDENTE  ...              2018-08-28
# 201706241353561        ACIDENTE  ...              2018-08-28
# 201710191757029        ACIDENTE  ...              2018-08-28
# 201707050515445        ACIDENTE  ...              2018-08-28
# 201706152048494        ACIDENTE  ...              2018-08-28
# ...                         ...  ...                     ...
# 201704031537231        ACIDENTE  ...              2018-08-28
# 201711271331205        ACIDENTE  ...              2018-08-28
# 201707061920096        ACIDENTE  ...              2018-08-28
# 201709121317043        ACIDENTE  ...              2018-08-28
# 201704150134378        ACIDENTE  ...              2018-08-28
#
# [142 rows x 21 columns]

# %%
data.shape
# Out:
# (5208, 21)
